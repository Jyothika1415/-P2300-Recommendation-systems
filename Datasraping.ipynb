# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyothika1415/P2-Recommendationsystems/blob/main/Datasraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.imdb.com/search/title/?title_type=feature&num_votes=10000,&sort=user_rating,desc&start=7551'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
movie_title = []
year = []
rating = []
metascore = []
grossincome = []
votes = []
runtime = []
genre = []
certificate = []
description = []
director_stars = []
movie_data = soup.findAll('div', attrs= {'class': 'lister-item mode-advanced'})

# %%
for store in movie_data:
    name = store.h3.a.text
    movie_title.append(name)

    year_of_release = store.h3.find('span', class_ = 'lister-item-year text-muted unbold').text.replace('(','').replace(')','')
    year.append(year_of_release)

    ratings = store.find('div', class_ = 'inline-block ratings-imdb-rating').text.replace('\n', '')
    rating.append(ratings)

    metascores = store.find('span', class_ = 'metascore').text.replace(' ', '') if store.find('span', class_ = 'metascore') else '$$$$'
    metascore.append(metascores)

    value = store.find_all('span', attrs = {'name': 'nv'})

    vote = value[0].text
    votes.append(vote)

    gross = value[1].text if len(value) > 1 else '$$$'
    grossincome.append(gross)

    run = store.p.find('span', class_ = 'runtime').text.replace('min', '')
    runtime.append(run)

    genres = store.p.find('span', class_ = 'genre').text.replace('\n', '').replace(' ', '')
    genre.append(genres)

    cert = store.p.find('span', class_ = 'certificate').text if store.p.find('span', class_ = 'certificate') else 'none'
    certificate.append(cert)

    des = (store.find_all('p', class_ = 'text-muted'))
    desc_text = ''
    for element in des:
        desc_text = element.text.strip()
    description.append(desc_text)

    director_s = store.find('p', class_ = '')

    dir_text = director_s.get_text(strip=True)
    director_stars.append(dir_text)

# %%
#Extract URL for the next web page for web scrapping
# url_e = store.find("a", class_="lister-page-next next-page", href= True)
# if url_e:
#     url= ("https://www.imdb.com" + url_e['href'])
# else:
#     print("Complete")

# %%
# Create a Pandas DataFrame
data17= pd.DataFrame({
    "Movie Title": movie_title,
    "Description": description,
    "Genre": genre,
    "Rating": rating,
    "Director_Actor" : director_stars,
    "Metascore" : metascore,
    "Gross_Income" : grossincome,
    "Votes" : votes,
    "Runtime" : runtime,
    "Certificate" : certificate,
    "Year" : year,
                  })

# %%
data3.head(5)
# Out:
#              Movie Title                                        Description  \
# 0                  Dolls  A dysfunctional family of three stop by a mans...
# 1  Because of Winn-Dixie  A mischievous dog befriends a lonely young gir...
# 2         The Laundromat  A widow investigates an insurance fraud, chasi...
# 3              Somewhere  After withdrawing to the Chateau Marmont, a pa...
# 4          Osmosis Jones  A policeman white blood cell, with the help of...
#
#                         Genre Rating  \
# 0                      Horror    6.3
# 1         Comedy,Drama,Family    6.3
# 2          Comedy,Crime,Drama    6.3
# 3        Comedy,Drama,Romance    6.3
# 4  Animation,Action,Adventure    6.3
#
#                                       Director_Actor Metascore Gross_Income  \
# 0  Director:Stuart Gordon|Stars:Ian Patrick Willi...        55          $$$
# 1  Director:Wayne Wang|Stars:AnnaSophia Robb,Jeff...        54      $32.65M
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Movie Title     50 non-null     object
#  1   Description     50 non-null     object
#  2   Genre           50 non-null     object
#  3   Rating          50 non-null     object
#  4   Director_Actor  50 non-null     object
#  5   Metascore       50 non-null     object
#  6   Gross_Income    50 non-null     object
#  7   Votes           50 non-null     object
#  8   Runtime         50 non-null     object
#  9   Certificate     50 non-null     object
#  10  Year            50 non-null     object
# dtypes: object(11)
# memory usage: 4.4+ KB

# %%
data17.to_csv('my_dataframe17.csv', index=False)

# %%
import string
alphabets = list(string.ascii_lowercase)
dataframe=[]
for i in range(1,18):
  file=f"my_dataframe{i}.csv"
  df = pd.read_csv(file)
  dataframe.append(df)

df_jyothi = pd.concat(dataframe,ignore_index=True)

# %%
df_jyothi
# Out:
#                                 Movie Title  \
# 0    Romy and Michele's High School Reunion
# 1                             Freaky Friday
# 2                             The Boss Baby
# 3                              Walking Tall
# 4                              The Sentinel
# ..                                      ...
# 845                                  Sphere
# 846                          The Collection
# 847                    Three Men and a Baby
# 848                         Hannibal Rising
# 849                           Hotel Artemis
#
#                                            Description  \
# 0    Two dim-witted, inseparable friends hit the ro...
# 1    An overworked mother and her daughter did not ...
# 2    A suit-wearing, briefcase-carrying baby pairs ...
# 3    A former U.S. soldier returns to his hometown ...
# 4    A young woman moves into an apartment in a bui...
# ..                                                 ...
# ...

# %%
df_jyothi.to_csv('df_jyothi.csv', index=False)

# %%
df_jyothi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Movie Title     850 non-null    object
#  1   Description     850 non-null    object
#  2   Genre           850 non-null    object
#  3   Rating          850 non-null    float64
#  4   Director_Actor  850 non-null    object
#  5   Metascore       850 non-null    object
#  6   Gross_Income    850 non-null    object
#  7   Votes           850 non-null    object
#  8   Runtime         850 non-null    int64
#  9   Certificate     850 non-null    object
#  10  Year            850 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 73.2+ KB

# %%
df_jyothi.head()
# Out:
#                               Movie Title  \
# 0  Romy and Michele's High School Reunion
# 1                           Freaky Friday
# 2                           The Boss Baby
# 3                            Walking Tall
# 4                            The Sentinel
#
#                                          Description  \
# 0  Two dim-witted, inseparable friends hit the ro...
# 1  An overworked mother and her daughter did not ...
# 2  A suit-wearing, briefcase-carrying baby pairs ...
# 3  A former U.S. soldier returns to his hometown ...
# 4  A young woman moves into an apartment in a bui...
#
#                         Genre  Rating  \
# 0                      Comedy     6.3
# 1       Comedy,Family,Fantasy     6.3
# 2  Animation,Adventure,Comedy     6.3
# 3                Action,Crime     6.3
# 4                      Horror     6.3
#
#                                       Director_Actor Metascore Gross_Income  \
# ...
